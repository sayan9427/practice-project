# %%
import pandas
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/Automobile_insurance_fraud.csv")
df
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       17-10-2014           OH
# 1                   228   42         342868       27-06-2006           IN
# 2                   134   29         687698       06-09-2000           OH
# 3                   256   41         227811       25-05-1990           IL
# 4                   228   44         367455       06-06-2014           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
df=pd.DataFrame(data=df)
df
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       17-10-2014           OH
# 1                   228   42         342868       27-06-2006           IN
# 2                   134   29         687698       06-09-2000           OH
# 3                   256   41         227811       25-05-1990           IL
# 4                   228   44         367455       06-06-2014           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
# converting '?' to nan and then replace with major value

df['police_report_available'].replace(('?','Nan'),inplace=True)

# %%
df
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       17-10-2014           OH
# 1                   228   42         342868       27-06-2006           IN
# 2                   134   29         687698       06-09-2000           OH
# 3                   256   41         227811       25-05-1990           IL
# 4                   228   44         367455       06-06-2014           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       17-10-2014           OH
# 1                 228   42         342868       27-06-2006           IN
# 2                 134   29         687698       06-09-2000           OH
# 3                 256   41         227811       25-05-1990           IL
# 4                 228   44         367455       06-06-2014           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# ...

# %%
df.tail()
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 995   500/1000               1000                1310.80               0
# 996    100/300               1000                1436.79               0
# 997    250/500                500                1383.49         3000000
# 998   500/1000               2000                1356.92         5000000
# 999    250/500               1000                 766.19               0
#
#      insured_zip  ... police_report_available total_claim_amount injury_claim  \
# ...

# %%
df.dtypes
# Out:
# months_as_customer               int64
# age                              int64
# policy_number                    int64
# policy_bind_date                object
# policy_state                    object
# policy_csl                      object
# policy_deductable                int64
# policy_annual_premium          float64
# umbrella_limit                   int64
# insured_zip                      int64
# insured_sex                     object
# insured_education_level         object
# insured_occupation              object
# insured_hobbies                 object
# insured_relationship            object
# capital-gains                    int64
# capital-loss                     int64
# incident_date                   object
# incident_type                   object
# collision_type                  object
# incident_severity               object
# authorities_contacted           object
# incident_state                  object
# incident_city                   object
# ...

# %%
df.drop(['policy_csl'],axis=1,inplace=True)

# %%
df.drop(['insured_hobbies'],axis=1,inplace=True)

# %%
df.drop(['insured_relationship'],axis=1,inplace=True)

# %%
df.drop(['_c39'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_number', 'policy_bind_date',
#        'policy_state', 'policy_deductable', 'policy_annual_premium',
#        'umbrella_limit', 'insured_zip', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'capital-gains',
#        'capital-loss', 'incident_date', 'incident_type', 'collision_type',
#        'incident_severity', 'authorities_contacted', 'incident_state',
#        'incident_city', 'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# months_as_customer             0
# age                            0
# policy_number                  0
# policy_bind_date               0
# policy_state                   0
# policy_deductable              0
# policy_annual_premium          0
# umbrella_limit                 0
# insured_zip                    0
# insured_sex                    0
# insured_education_level        0
# insured_occupation             0
# capital-gains                  0
# capital-loss                   0
# incident_date                  0
# incident_type                  0
# collision_type                 0
# incident_severity              0
# authorities_contacted          0
# incident_state                 0
# incident_city                  0
# incident_location              0
# incident_hour_of_the_day       0
# number_of_vehicles_involved    0
# property_damage                0
# bodily_injuries                0
# witnesses                      0
# police_report_available        0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 36 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_deductable            1000 non-null   int64
#  6   policy_annual_premium        1000 non-null   float64
#  7   umbrella_limit               1000 non-null   int64
#  8   insured_zip                  1000 non-null   int64
#  9   insured_sex                  1000 non-null   object
#  10  insured_education_level      1000 non-null   object
#  11  insured_occupation           1000 non-null   object
#  12  capital-gains                1000 non-null   int64
# ...

# %%
df.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_number', 'policy_bind_date',
#        'policy_state', 'policy_deductable', 'policy_annual_premium',
#        'umbrella_limit', 'insured_zip', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'capital-gains',
#        'capital-loss', 'incident_date', 'incident_type', 'collision_type',
#        'incident_severity', 'authorities_contacted', 'incident_state',
#        'incident_city', 'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported'],
#       dtype='object')

# %%
import sklearn
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

# %%
le=LabelEncoder()
list1=['policy_bind_date','fraud_reported','auto_model','auto_make','police_report_available','incident_location','incident_city','incident_state','authorities_contacted','incident_severity','collision_type','incident_type','incident_date','insured_occupation','insured_education_level','policy_state','insured_sex','property_damage']
for i in list1:
    df[i]=le.fit_transform(df[i].astype(str))
df
# Out:
#      months_as_customer  age  policy_number  policy_bind_date  policy_state  \
# 0                   328   48         521585               426             2
# 1                   228   42         342868               783             1
# 2                   134   29         687698               948             2
# 3                   256   41         227811               714             0
# 4                   228   44         367455               912             0
# ..                  ...  ...            ...               ...           ...
# 995                   3   38         941851               370             2
# 996                 285   41         186934               268             0
# 997                 130   34         918516               397             2
# 998                 458   62         533940               476             0
# 999                 456   60         556080               211             2
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 36 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   int32
#  4   policy_state                 1000 non-null   int32
#  5   policy_deductable            1000 non-null   int64
#  6   policy_annual_premium        1000 non-null   float64
#  7   umbrella_limit               1000 non-null   int64
#  8   insured_zip                  1000 non-null   int64
#  9   insured_sex                  1000 non-null   int32
#  10  insured_education_level      1000 non-null   int32
#  11  insured_occupation           1000 non-null   int32
#  12  capital-gains                1000 non-null   int64
# ...

# %%
df.plot(kind='box',subplots=True,layout=(6,12))
# Out:
# months_as_customer                AxesSubplot(0.125,0.772143;0.0545775x0.107857)
# age                            AxesSubplot(0.190493,0.772143;0.0545775x0.107857)
# policy_number                  AxesSubplot(0.255986,0.772143;0.0545775x0.107857)
# policy_bind_date               AxesSubplot(0.321479,0.772143;0.0545775x0.107857)
# policy_state                   AxesSubplot(0.386972,0.772143;0.0545775x0.107857)
# policy_deductable              AxesSubplot(0.452465,0.772143;0.0545775x0.107857)
# policy_annual_premium          AxesSubplot(0.517958,0.772143;0.0545775x0.107857)
# umbrella_limit                 AxesSubplot(0.583451,0.772143;0.0545775x0.107857)
# insured_zip                    AxesSubplot(0.648944,0.772143;0.0545775x0.107857)
# insured_sex                    AxesSubplot(0.714437,0.772143;0.0545775x0.107857)
# insured_education_level         AxesSubplot(0.77993,0.772143;0.0545775x0.107857)
# insured_occupation             AxesSubplot(0.845423,0.772143;0.0545775x0.107857)
# ...

# %%
for i in df.columns:
    plt.figure()
    sns.distplot(df[i])

# %%
df.hist(grid=False,
       figsize=(10, 6),
       bins=30)
# Out:
# array([[<AxesSubplot:title={'center':'months_as_customer'}>,
#         <AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'policy_number'}>,
#         <AxesSubplot:title={'center':'policy_bind_date'}>,
#         <AxesSubplot:title={'center':'policy_state'}>,
#         <AxesSubplot:title={'center':'policy_deductable'}>],
#        [<AxesSubplot:title={'center':'policy_annual_premium'}>,
#         <AxesSubplot:title={'center':'umbrella_limit'}>,
#         <AxesSubplot:title={'center':'insured_zip'}>,
#         <AxesSubplot:title={'center':'insured_sex'}>,
#         <AxesSubplot:title={'center':'insured_education_level'}>,
#         <AxesSubplot:title={'center':'insured_occupation'}>],
#        [<AxesSubplot:title={'center':'capital-gains'}>,
#         <AxesSubplot:title={'center':'capital-loss'}>,
#         <AxesSubplot:title={'center':'incident_date'}>,
#         <AxesSubplot:title={'center':'incident_type'}>,
# ...

# %%
df.describe()
# Out:
#        months_as_customer          age  policy_number  policy_bind_date  \
# count         1000.000000  1000.000000    1000.000000       1000.000000
# mean           203.954000    38.948000  546238.648000        473.171000
# std            115.113174     9.140287  257063.005276        275.769818
# min              0.000000    19.000000  100804.000000          0.000000
# 25%            115.750000    32.000000  335980.250000        234.750000
# 50%            199.500000    38.000000  533135.000000        476.500000
# 75%            276.250000    44.000000  759099.750000        713.250000
# max            479.000000    64.000000  999435.000000        950.000000
#
#        policy_state  policy_deductable  policy_annual_premium  umbrella_limit  \
# count    1000.00000        1000.000000            1000.000000    1.000000e+03
# mean        1.01400        1136.000000            1256.406150    1.101000e+06
# std         0.83096         611.864673             244.167395    2.297407e+06
# ...

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
#      months_as_customer       age  policy_number  policy_bind_date  \
# 0              1.078140  0.990836       0.095953          0.171138
# 1              0.208995  0.334073       0.791527          1.124068
# 2              0.608002  1.088913       0.550566          1.722692
# 3              0.452355  0.224613       1.239334          0.873734
# 4              0.208995  0.552994       0.695834          1.592084
# ..                  ...       ...            ...               ...
# 995            1.746582  0.103769       1.539740          0.374307
# 996            0.704407  0.224613       1.398429          0.744366
# 997            0.642767  0.541611       1.448920          0.276350
# 998            2.208028  2.523284       0.047867          0.010264
# 999            2.190645  2.304363       0.038303          0.951163
#
#      policy_state  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0        1.187173           0.222383               0.616705        0.479476
# ...

# %%
z.isnull().sum()
# Out:
# months_as_customer             0
# age                            0
# policy_number                  0
# policy_bind_date               0
# policy_state                   0
# policy_deductable              0
# policy_annual_premium          0
# umbrella_limit                 0
# insured_zip                    0
# insured_sex                    0
# insured_education_level        0
# insured_occupation             0
# capital-gains                  0
# capital-loss                   0
# incident_date                  0
# incident_type                  0
# collision_type                 0
# incident_severity              0
# authorities_contacted          0
# incident_state                 0
# incident_city                  0
# incident_location              0
# incident_hour_of_the_day       0
# number_of_vehicles_involved    0
# property_damage                0
# bodily_injuries                0
# witnesses                      0
# police_report_available        0
# ...

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 31,  48,  88, 115, 119, 229, 248, 262, 314, 430, 458, 500, 503,
#        657, 700, 763, 807, 875, 922, 975], dtype=int64), array([ 7,  7,  7,  7,  7,  6,  6,  7,  7,  7,  7, 30,  7,  7,  7,  6, 13,
#         7,  7,  7], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#      months_as_customer  age  policy_number  policy_bind_date  policy_state  \
# 0                   328   48         521585               426             2
# 1                   228   42         342868               783             1
# 2                   134   29         687698               948             2
# 3                   256   41         227811               714             0
# 4                   228   44         367455               912             0
# ..                  ...  ...            ...               ...           ...
# 995                   3   38         941851               370             2
# 996                 285   41         186934               268             0
# 997                 130   34         918516               397             2
# 998                 458   62         533940               476             0
# 999                 456   60         556080               211             2
#
# ...

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 980 entries, 0 to 999
# Data columns (total 36 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           980 non-null    int64
#  1   age                          980 non-null    int64
#  2   policy_number                980 non-null    int64
#  3   policy_bind_date             980 non-null    int32
#  4   policy_state                 980 non-null    int32
#  5   policy_deductable            980 non-null    int64
#  6   policy_annual_premium        980 non-null    float64
#  7   umbrella_limit               980 non-null    int64
#  8   insured_zip                  980 non-null    int64
#  9   insured_sex                  980 non-null    int32
#  10  insured_education_level      980 non-null    int32
#  11  insured_occupation           980 non-null    int32
#  12  capital-gains                980 non-null    int64
# ...

# %%
df_new.skew()
# Out:
# months_as_customer             0.362608
# age                            0.475385
# policy_number                  0.036283
# policy_bind_date              -0.004405
# policy_state                  -0.038157
# policy_deductable              0.476090
# policy_annual_premium          0.035964
# umbrella_limit                 1.801424
# insured_zip                    0.837283
# insured_sex                    0.139324
# insured_education_level        0.006286
# insured_occupation             0.053107
# capital-gains                  0.466619
# capital-loss                  -0.376884
# incident_date                  0.007309
# incident_type                  0.090563
# collision_type                -0.194015
# incident_severity              0.277726
# authorities_contacted         -0.114044
# incident_state                -0.149255
# incident_city                  0.043882
# incident_location             -0.001427
# incident_hour_of_the_day      -0.039280
# ...

# %%
df_new['months_as_customer']=np.sqrt(df_new['months_as_customer'])

# %%
df_new['vehicle_claim']=np.sqrt(df_new['vehicle_claim'])

# %%
df_new['umbrella_limit']=np.sqrt(df_new['umbrella_limit'])

# %%
df_new['insured_zip']=np.sqrt(df_new['insured_zip'])

# %%
df_new['incident_severity']=np.sqrt(df_new['incident_severity'])

# %%
df_new['age']=np.sqrt(df_new['age'])

# %%
df_new['number_of_vehicles_involved']=np.sqrt(df_new['number_of_vehicles_involved'])

# %%
df_new['total_claim_amount']=np.sqrt(df_new['total_claim_amount'])

# %%
df_new['capital-gains']=np.sqrt(df_new['capital-gains'])

# %%
df_new['policy_annual_premium']=np.sqrt(df_new['policy_annual_premium'])

# %%
df_new['vehicle_claim']=np.sqrt(df_new['vehicle_claim'])

# %%
df_new['property_claim']=np.sqrt(df_new['property_claim'])

# %%
df_new['injury_claim']=np.sqrt(df_new['injury_claim'])

# %%
df_new.corr()
# Out:
#                              months_as_customer       age  policy_number  \
# months_as_customer                     1.000000  0.864781       0.058015
# age                                    0.864781  1.000000       0.060810
# policy_number                          0.058015  0.060810       1.000000
# policy_bind_date                       0.043625  0.035841       0.030436
# policy_state                          -0.001726 -0.021713       0.071343
# policy_deductable                      0.025774  0.032673      -0.009812
# policy_annual_premium                  0.003388  0.010907       0.027021
# umbrella_limit                         0.003691  0.002206      -0.003837
# insured_zip                            0.024797  0.036149       0.004656
# insured_sex                            0.053044  0.072389       0.007069
# insured_education_level                0.000973  0.003340      -0.033767
# insured_occupation                     0.014883 -0.004488       0.016556
# ...

# %%
sns.heatmap(df_new.corr(),annot=True,linewidth=0.5)
# Out:
# <AxesSubplot:>

# %%
df_new.corr()['fraud_reported'].sort_values()
# Out:
# incident_severity             -0.473692
# incident_state                -0.052027
# authorities_contacted         -0.043636
# incident_type                 -0.040893
# incident_city                 -0.039434
# policy_number                 -0.036887
# property_damage               -0.028548
# incident_location             -0.021297
# capital-loss                  -0.017617
# capital-gains                 -0.016167
# policy_annual_premium         -0.014673
# auto_year                      0.001152
# incident_hour_of_the_day       0.004326
# age                            0.009674
# insured_zip                    0.011104
# months_as_customer             0.012415
# incident_date                  0.012834
# insured_education_level        0.013116
# policy_deductable              0.015774
# insured_sex                    0.020582
# police_report_available        0.029094
# auto_model                     0.030172
# auto_make                      0.034584
# ...

# %%
df_new.dropna(inplace=True)

# %%
df_new
# Out:
#      months_as_customer       age  policy_number  policy_bind_date  \
# 0             18.110770  6.928203         521585               426
# 1             15.099669  6.480741         342868               783
# 2             11.575837  5.385165         687698               948
# 3             16.000000  6.403124         227811               714
# 4             15.099669  6.633250         367455               912
# ..                  ...       ...            ...               ...
# 995            1.732051  6.164414         941851               370
# 996           16.881943  6.403124         186934               268
# 997           11.401754  5.830952         918516               397
# 998           21.400935  7.874008         533940               476
# 999           21.354157  7.745967         556080               211
#
#      policy_state  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0               2               1000              37.508799        0.000000
# ...

# %%
x=df_new.drop(["fraud_reported"],axis=1)
x
# Out:
#      months_as_customer       age  policy_number  policy_bind_date  \
# 0             18.110770  6.928203         521585               426
# 1             15.099669  6.480741         342868               783
# 2             11.575837  5.385165         687698               948
# 3             16.000000  6.403124         227811               714
# 4             15.099669  6.633250         367455               912
# ..                  ...       ...            ...               ...
# 995            1.732051  6.164414         941851               370
# 996           16.881943  6.403124         186934               268
# 997           11.401754  5.830952         918516               397
# 998           21.400935  7.874008         533940               476
# 999           21.354157  7.745967         556080               211
#
#      policy_state  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0               2               1000              37.508799        0.000000
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
x.shape
# Out:
# (979, 35)

# %%
x.shape[1]
# Out:
# 35

# %%
def vif_calc():
    vif=pd.DataFrame()
    vif["vif factor"]=[variance_inflation_factor(x.values,i)for i in range(x.shape[1])]
    vif['features']=x.columns
    print(vif)

# %%
vif_calc()
# Out:
#      vif factor                     features
# 0     41.702063           months_as_customer
# 1    298.682715                          age
# 2      5.624947                policy_number
# 3      4.107796             policy_bind_date
# 4      2.595420                 policy_state
# 5      4.656427            policy_deductable
# 6    108.312019        policy_annual_premium
# 7      1.261613               umbrella_limit
# 8    213.953025                  insured_zip
# 9      1.921999                  insured_sex
# 10     3.419456      insured_education_level
# 11     3.704167           insured_occupation
# 12     1.991662                capital-gains
# 13     1.975543                 capital-loss
# 14     4.129311                incident_date
# 15    12.202088                incident_type
# 16     7.044102               collision_type
# 17     3.830486            incident_severity
# 18     3.272211        authorities_contacted
# 19     3.392596               incident_state
# ...

# %%
y=df_new.iloc[:,-1]
y
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 995    0
# 996    0
# 997    0
# 998    0
# 999    0
# Name: fraud_reported, Length: 979, dtype: int32

# %%
y.value_counts()
# Out:
# 0    739
# 1    240
# Name: fraud_reported, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
#sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 1.01526568,  0.99852348, -0.0958053 , ..., -0.17481224,
#         -1.60435585, -0.19027395],
#        [ 0.33890283,  0.38506928, -0.78992431, ..., -0.67742951,
#          1.28505261,  0.30913141],
#        [-0.45263113, -1.1169238 ,  0.54936104, ...,  1.33303957,
#         -0.15965162,  0.30913141],
#        ...,
#        [-0.49173411, -0.50576657,  1.44583515, ...,  0.0764964 ,
#         -1.42376782, -1.52202158],
#        [ 1.75431249,  2.29518584, -0.04781971, ..., -1.43135541,
#          0.83358254, -1.18908468],
#        [ 1.74380506,  2.11964623,  0.03816985, ..., -0.67742951,
#          1.28505261,  0.30913141]])

# %%
from imblearn import under_sampling, over_sampling

# %%
from imblearn.over_sampling import SMOTE

# %%
smt=SMOTE()
dfx,dfy=smt.fit_resample(x,y)

# %%
dfy.value_counts()
# Out:
# 1    739
# 0    739
# Name: fraud_reported, dtype: int64

# %%
import sklearn
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(dfx,dfy,test_size=.30,random_state=45)

# %%
rf=RandomForestClassifier(n_estimators=100,random_state=45)
lg=LogisticRegression()
knn=KNeighborsClassifier()
dtc=DecisionTreeClassifier()
svc=SVC()
model=[rf,lg,knn,dtc,svc]
for m in model:
    m.fit(x_train,y_train)
    predm=m.predict(x_test)
    print('accuracy_score of',m ,'is:')
    print(accuracy_score(y_test,predm))
    print(confusion_matrix(y_test,predm))
    print(classification_report(y_test,predm))
# Out:
# accuracy_score of RandomForestClassifier(random_state=45) is:
# 0.8761261261261262
# [[206  24]
#  [ 31 183]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.90      0.88       230
#            1       0.88      0.86      0.87       214
#
#     accuracy                           0.88       444
#    macro avg       0.88      0.88      0.88       444
# weighted avg       0.88      0.88      0.88       444
#
# accuracy_score of LogisticRegression() is:
# 0.7905405405405406
# [[178  52]
#  [ 41 173]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.77      0.79       230
#            1       0.77      0.81      0.79       214
#
#     accuracy                           0.79       444
#    macro avg       0.79      0.79      0.79       444
# weighted avg       0.79      0.79      0.79       444
#
# accuracy_score of KNeighborsClassifier() is:
# 0.6869369369369369
# [[100 130]
#  [  9 205]]
# ...

# %%
from sklearn.ensemble import GradientBoostingClassifier
gb=GradientBoostingClassifier()
gb.fit(x_train,y_train)
predgb=gb.predict(x_test)
print(accuracy_score(y_test,predgb))
print(confusion_matrix(y_test,predgb))
print(classification_report(y_test,predgb))
# Out:
# 0.8716216216216216
# [[203  27]
#  [ 30 184]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.88      0.88       230
#            1       0.87      0.86      0.87       214
#
#     accuracy                           0.87       444
#    macro avg       0.87      0.87      0.87       444
# weighted avg       0.87      0.87      0.87       444

# %%
predrf=rf.predict(x_test)
from sklearn.model_selection import cross_val_score
rfs=accuracy_score(y_test,predrf)
for j in range(2,10):
    rfscore=cross_val_score(rf,x,y,cv=j)
    rfcv=rfscore.mean()
    print('at cv:-',j)
    print('crossvalidation score:',rfcv*100)
    print('accuracy_score is:-',rfs*100)
    print('\n')
# Out:
# at cv:- 2
# crossvalidation score: 77.52869245857852
# accuracy_score is:- 87.61261261261262
#
#
# at cv:- 3
# crossvalidation score: 76.50513123581172
# accuracy_score is:- 87.61261261261262
#
#
# at cv:- 4
# crossvalidation score: 77.93701906992305
# accuracy_score is:- 87.61261261261262
#
#
# at cv:- 5
# crossvalidation score: 76.91784406070121
# accuracy_score is:- 87.61261261261262
#
#
# at cv:- 6
# crossvalidation score: 79.46842735298519
# accuracy_score is:- 87.61261261261262
#
#
# at cv:- 7
# crossvalidation score: 77.02099544853913
# accuracy_score is:- 87.61261261261262
#
#
# at cv:- 8
# crossvalidation score: 78.14207650273224
# accuracy_score is:- 87.61261261261262
#
#
# at cv:- 9
# crossvalidation score: 77.33227621097143
# accuracy_score is:- 87.61261261261262

# %%
RandomForestClassifier()
# Out:
# RandomForestClassifier()

# %%
from sklearn.model_selection import GridSearchCV
parameters={'max_features':['auto','sqrt','log2'],
            'max_depth':[4,5,6,7,8],
            'criterion':['gini','entropy'],
            'n_estimators':[100,200,300,400]}

# %%
gcv=GridSearchCV(estimator=rf,
                 param_grid= parameters,
                 cv=6)

# %%
gcv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=6, estimator=RandomForestClassifier(random_state=45),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [4, 5, 6, 7, 8],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [100, 200, 300, 400]})

# %%
gcv.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 8,
#  'max_features': 'auto',
#  'n_estimators': 200}

# %%
gcv_pred=gcv.best_estimator_.predict(x_test)
accuracy_score(y_test,gcv_pred)
# Out:
# 0.8761261261261262

# %%
gcv.best_score_
# Out:
# 0.8665423219966842

# %%
from sklearn.metrics import plot_roc_curve
plot_roc_curve(gcv.best_estimator_,x_test,y_test)
plt.title("AUC ROC PLOT")
plt.show()

# %%
import joblib

# %%
#saving best model with gcv.best_estimator_


joblib.dump(gcv.best_estimator_,'rffile_Insurance Claims- Fraud Detection Project.obj')
# Out:
# ['rffile_Insurance Claims- Fraud Detection Project.obj']
